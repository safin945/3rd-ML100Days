# %%
import os
import numpy as np
import pandas as pd
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split,KFold,GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor,RandomForestClassifier

# %%
# load file
dir_path = '/Users/safin.yeh/Documents/3rd-ML100Days/Homework'
test_data = os.path.join(dir_path,'test.csv')
train_data = os.path.join(dir_path,'train.csv')
trainLabels = os.path.join(dir_path,'trainLabels.csv')

testdata = pd.read_csv(test_data,header=None)
traindata = pd.read_csv(train_data,header=None)
trainLabelsdata = pd.read_csv(trainLabels,header=None)

testdata.shape, traindata.shape, trainLabelsdata.shape
# Out:
# ((9000, 40), (1000, 40), (1000, 1))

# %%
testdata.describe()
# Out:
#                 0            1            2            3            4   \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.011814     0.004261    -0.001708     0.008614     1.262429
# std       1.009514     1.011432     0.996685     0.989010     4.527492
# min      -3.568633    -4.238067    -3.587473    -3.646144   -17.296514
# 25%      -0.669886    -0.678792    -0.665240    -0.662560    -1.669099
# 50%       0.006104     0.010758     0.007384     0.009027     1.123982
# 75%       0.703350     0.684755     0.658111     0.683506     4.002391
# max       3.843549     3.538868     3.716102     3.667817    20.551947
#
#                 5            6            7            8            9   ...  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000  ...
# mean      0.006003     0.480585    -0.017228     0.006883    -0.006664  ...
# std       0.999623     2.102394     2.204673     0.989207     0.991570  ...
# ...

# %%
traindata.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597  ...
# std       0.989128     2.118819     2.232256     1.001064     1.013520  ...
# ...

# %%
trainLabelsdata.describe()
# Out:
#                 0
# count  1000.00000
# mean      0.51000
# std       0.50015
# min       0.00000
# 25%       0.00000
# 50%       1.00000
# 75%       1.00000
# max       1.00000

# %%
x_train,x_test,y_train,y_test = train_test_split(traindata,trainLabelsdata,test_size=0.2,random_state=400)

clf= RandomForestClassifier(n_estimators = 100 , max_depth=10)

clf.fit(x_train,y_train.values.ravel())

y_pred = clf.predict(testdata)

print(y_pred.shape)

y_pred

#acc=metrics.mean_squared_error(y_test,y_pred)
#acc = metrics.accuracy_score(y_test,y_pred)

#print(acc)
# Out:
# (9000,)
# array([1, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
pd_y_pred = pd.DataFrame(y_pred)

pd_y_pred.columns = ['Solution']
pd_y_pred['Id'] = np.arange(1,pd_y_pred.shape[0]+1)

pd_y_pred = pd_y_pred[['Id','Solution']]
pd_y_pred
# Out:
#         Id  Solution
# 0        1         1
# 1        2         0
# 2        3         0
# 3        4         0
# 4        5         0
# 5        6         0
# 6        7         0
# 7        8         1
# 8        9         0
# 9       10         0
# 10      11         1
# 11      12         1
# 12      13         1
# 13      14         1
# 14      15         0
# 15      16         1
# 16      17         0
# 17      18         1
# 18      19         1
# 19      20         1
# 20      21         0
# 21      22         1
# 22      23         0
# 23      24         0
# 24      25         1
# 25      26         1
# 26      27         1
# 27      28         0
# 28      29         1
# 29      30         0
# ...    ...       ...
# 8970  8971         1
# 8971  8972         0
# 8972  8973         1
# 8973  8974         1
# 8974  8975         0
# 8975  8976         1
# 8976  8977         0
# 8977  8978         1
# 8978  8979         1
# 8979  8980         1
# 8980  8981         1
# ...

# %%
pd_y_pred.to_csv('HW48.csv',index = False)
